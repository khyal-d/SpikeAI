# %%
# curl --location 'http://3.110.18.218/key/info' \
# --header 'Authorization: Bearer sk-YFSTOr9gflSBWfxmiG4MBA'

# %%
import requests
from utils.packages import *

# %%
from app.main import *

# %%
# Give me a daily breakdown of page views, number of events and active users event for mobile users and India Country for the /pricing page over the last 20 minutes and summarize trends.
# Give me a daily breakdown of page views, users, and sessions for the /pricing page over the last 14 days and summarize trends.
query_obj = AnalyticsRequest(
    propertyId="516806940",
    query="Give me a daily breakdown of page views, number of events and active users event for mobile users and India Country for the /pricing page over the last 20 minutes and summarize trends."
)

# %%
res = analytics_query(query_obj)
# Out:
# 2025-12-19 13:08:00.707 | INFO     | app.nl_parser:llm_parse:17 - LLM Parse Running
# 2025-12-19 13:08:00.710 | INFO     | app.nl_parser:llm_parse:19 - Client Initialized
# 2025-12-19 13:08:00.712 | INFO     | app.nl_parser:llm_parse:90 - prompt is :-
#         You are a Google Analytics 4 (GA4) query parsing agent.
#
# Your task is to convert a natural-language analytics question into a
# STRUCTURED, GA4-EXECUTABLE QUERY.
#
# You MUST follow GA4 Data API semantics.
#
# ----------------------------------
# INPUT
# ----------------------------------
# Natural language query:
# Give me a daily breakdown of page views, number of events and active users event for mobile users and India Country for the /pricing page over the last 20 minutes and summarize trends.
#
# ----------------------------------
# WHAT TO EXTRACT
# ----------------------------------
#
# ...

# %%
res
# Out:
# {'metadata': {'propertyId': '516806940',
#   'mode': 'realtime',
#   'metrics': ['screenPageViews', 'eventCount', 'activeUsers'],
#   'dimensions': ['minutesAgo'],
#   'duration': [(20, 0)],
#   'page_path': '/pricing'},
#  'data': ([], [(20, 0)]),
#  'summary': {'summary': 'No data was found for the requested criteria (page views, events, and active users for mobile users in India on the /pricing page over the last 20 minutes). Therefore, no trends or specific insights can be provided at this time.',
#   'trends': [],
#   'anomalies': [],
#   'dimension_insights': []}}

# %%
res
# Out:
# {'metadata': {'propertyId': '516806940',
#   'mode': 'core',
#   'metrics': ['screenPageViews', 'totalUsers', 'sessions'],
#   'dimensions': ['date'],
#   'duration': ['2025-12-05', '2025-12-19'],
#   'page_path': '/pricing'},
#  'data': [],
#  'summary': {'summary': 'The requested GA4 report data for the /pricing page over the last 14 days (2025-12-05 to 2025-12-19) is empty. Therefore, no analysis of page views, users, or sessions can be performed, and no trends or anomalies can be identified.',
#   'trends': [],
#   'anomalies': [],
#   'dimension_insights': []}}

# %%
from app.nl_parser import *

# %%
res = llm_parse(query_obj.query)
# Out:
# 2025-12-19 03:15:31.334 | INFO     | app.nl_parser:llm_parse:17 - LLM Parse Running
# 2025-12-19 03:15:31.338 | INFO     | app.nl_parser:llm_parse:19 - Client Initialized
# 2025-12-19 03:15:31.341 | INFO     | app.nl_parser:llm_parse:84 - prompt is :-
#         You are a Google Analytics 4 (GA4) query parsing agent.
#
# Your task is to convert a natural-language analytics question into a
# STRUCTURED, GA4-EXECUTABLE QUERY.
#
# You MUST follow GA4 Data API semantics.
#
# ----------------------------------
# INPUT
# ----------------------------------
# Natural language query:
# Give me the number of 1-day active users, Ecommerce purchase, sessions that were engaged, average events per session for last 11 days
#
# ----------------------------------
# WHAT TO EXTRACT
# ----------------------------------
#
# 1. METRICS
# - Return ONLY GA4 Data API metric names (camelCase)
# - Examples:
#   screenPageViews, totalUsers, activeUsers, sessions,
#   engagementRate, eventCount, purchaseRevenue
# ...

# %%
res
# Out:
# {'metrics': ['activeUsers',
#   'purchases',
#   'engagedSessions',
#   'eventCountPerSession'],
#  'dimensions': [],
#  'days': 11}

# %%
metrics, dimensions = validate_with_auto_repair(
            client,
            query_obj.propertyId,
            res["metrics"],
            res["dimensions"]
        )

# %%
metrics
# Out:
# ['activeUsers', 'ecommercePurchases', 'engagedSessions', 'eventsPerSession']

# %%
dimensions
# Out:
# []
